# %% [markdown]
# <a href="https://colab.research.google.com/github/LifelessPROgrammer/SEM3AAI/blob/main/Implement_Conditional_Probability_And_Joint_Probability_using_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Conditional Probability

# %%
def conditional():
    pass_stats = 0.25
    pass_codingWStats = 0.50
    pass_codingWOStats = 0.30
    prob_both = pass_stats * pass_codingWStats
    print("The Probability that applicant passes both is", round(prob_both,3))
    prob_coding = (prob_both) + ((1-pass_stats)*pass_codingWOStats)
    print("Probablity that he/she passes only coding is", round(prob_coding,3))
    stats_given_coding = prob_both/prob_coding
    print("Conditional probablity is", round(stats_given_coding, 3))

print("Hey Aditya")
conditional()
# Out:
# Hey Aditya
# The Probability that applicant passes both is 0.125
# Probablity that he/she passes only coding is 0.35
# Conditional probablity is 0.357

# %% [markdown]
# Joint Probability

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load data
data = pd.read_csv('mall.csv', header=None, names=['x', 'y'])

# Convert 'x' and 'y' columns to numeric data
data['x'] = pd.to_numeric(data['x'], errors='coerce')
data['y'] = pd.to_numeric(data['y'], errors='coerce')

# Create joint plot
sns.jointplot(data=data, x='x', y='y', kind='kde')

# Display the plot
plt.show()
